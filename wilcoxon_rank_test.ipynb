# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from scipy.stats import wilcoxon

# %%
df=pd.read_csv('WT_VS_DELC_EP_INT.txt',sep='\s+')
df
# Out:
#          WT    DELC
# 0   0.51000  0.1200
# 1   0.91000  0.0800
# 2   0.41000  0.1800
# 3   0.31400  0.1540
# 4   0.30000  0.1880
# 5   0.29500  0.1990
# 6   0.31100  0.2020
# 7   0.32850  0.2080
# 8   0.42540  0.1890
# 9   0.61000  0.6500
# 10  0.38000  0.3100
# 11  0.46000  0.2890
# 12  0.33000  0.2730
# 13  0.52000  0.2910
# 14  0.65000  0.3080
# 15  0.64000  0.3190
# 16  0.58000  0.3160
# 17  0.63000  0.2460
# 18  0.47200  0.2040
# 19  0.56000  0.1700
# 20  0.43268  0.1265
# 21  0.63230  0.2960
# 22  0.61200  0.3210
# 23  0.60700  0.3530
# 24  0.61400  0.3650
# 25  0.58900  0.3780
# 26  0.57100  0.5100
# 27  0.41000  0.3680
# 28  0.62500  0.3600
# 29  0.67300  0.2700
# 30  0.60800  0.3736
# 31  0.56100  0.3000
# 32  0.56600  0.3500
# 33  0.99000  0.6700
# 34  0.47000  0.3100
# 35  0.46000  0.1800
# 36  0.41000  0.2142
# 37  0.46000  0.3200
# 38  0.71000  0.3330
# 39  0.58000  0.2100
# 40  0.67000  0.3100
# 41  0.93000  0.3900
# 42  0.97000  0.7400
# 43  0.65000  0.2700

# %%
plt.figure(figsize=(5, 4))
ax = sns.boxplot(data=df,showfliers=False)
# plt.title('Box Plots of WT and DELC')

# Add significance marker
x1, x2 = 0, 1
y, h, col = df['WT'].max() + 0.05, 0.02, 'k'
plt.plot([x1, x1, x2, x2], [y, y+h, y+h, y], lw=1.5, c=col)
plt.text((x1+x2)*.5, y+h, "****", ha='center', va='bottom', color=col)
plt.ylabel('Contact probability')
plt.show()

# Perform Wilcoxon rank-sum test
stat, p_value = wilcoxon(df['WT'], df['DELC'])

stat, p_value
# Out:
# (1.0, 2.2737367544323206e-13)

# %%
pip install MDAnalysis
# Out:
# Note: you may need to restart the kernel to use updated packages.
# Collecting MDAnalysis
#   Downloading MDAnalysis-2.7.0-cp310-cp310-win_amd64.whl (4.0 MB)
#      ---------------------------------------- 4.0/4.0 MB 5.0 MB/s eta 0:00:00
# Requirement already satisfied: packaging in c:\users\user1\appdata\local\programs\python\python310\lib\site-packages (from MDAnalysis) (21.3)
# Collecting fasteners
#   Downloading fasteners-0.19-py3-none-any.whl (18 kB)
# Requirement already satisfied: matplotlib>=1.5.1 in c:\users\user1\appdata\local\programs\python\python310\lib\site-packages (from MDAnalysis) (3.7.2)
# Requirement already satisfied: scipy>=1.5.0 in c:\users\user1\appdata\local\programs\python\python310\lib\site-packages (from MDAnalysis) (1.11.3)
# Collecting joblib>=0.12
#   Downloading joblib-1.4.2-py3-none-any.whl (301 kB)
#      -------------------------------------- 301.8/301.8 kB 3.1 MB/s eta 0:00:00
# Collecting threadpoolctl
#   Downloading threadpoolctl-3.5.0-py3-none-any.whl (18 kB)
# Collecting mda-xdrlib
#   Downloading mda_xdrlib-0.2.0-py3-none-any.whl (14 kB)
# Collecting GridDataFormats>=0.4.0
#   Downloading GridDataFormats-1.0.2-py3-none-any.whl (2.1 MB)
#      ---------------------------------------- 2.1/2.1 MB 4.1 MB/s eta 0:00:00
# Collecting tqdm>=4.43.0
#   Downloading tqdm-4.66.4-py3-none-any.whl (78 kB)
#      ---------------------------------------- 78.3/78.3 kB 1.1 MB/s eta 0:00:00
# Requirement already satisfied: numpy<2.0,>=1.22.3 in c:\users\user1\appdata\local\programs\python\python310\lib\site-packages (from MDAnalysis) (1.23.2)
# Collecting mmtf-python>=1.0.0
#   Downloading mmtf_python-1.1.3-py2.py3-none-any.whl (25 kB)
# Collecting mrcfile
#   Downloading mrcfile-1.5.0-py2.py3-none-any.whl (44 kB)
#      ---------------------------------------- 44.1/44.1 kB 2.3 MB/s eta 0:00:00
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\user1\appdata\local\programs\python\python310\lib\site-packages (from matplotlib>=1.5.1->MDAnalysis) (4.41.0)
# Requirement already satisfied: pillow>=6.2.0 in c:\users\user1\appdata\local\programs\python\python310\lib\site-packages (from matplotlib>=1.5.1->MDAnalysis) (10.0.0)
# Requirement already satisfied: kiwisolver>=1.0.1 in c:\users\user1\appdata\local\programs\python\python310\lib\site-packages (from matplotlib>=1.5.1->MDAnalysis) (1.4.4)
# Requirement already satisfied: contourpy>=1.0.1 in c:\users\user1\appdata\local\programs\python\python310\lib\site-packages (from matplotlib>=1.5.1->MDAnalysis) (1.1.0)
# Requirement already satisfied: pyparsing<3.1,>=2.3.1 in c:\users\user1\appdata\local\programs\python\python310\lib\site-packages (from matplotlib>=1.5.1->MDAnalysis) (3.0.9)
# Requirement already satisfied: cycler>=0.10 in c:\users\user1\appdata\local\programs\python\python310\lib\site-packages (from matplotlib>=1.5.1->MDAnalysis) (0.11.0)
# Requirement already satisfied: python-dateutil>=2.7 in c:\users\user1\appdata\local\programs\python\python310\lib\site-packages (from matplotlib>=1.5.1->MDAnalysis) (2.8.2)
# Collecting msgpack>=1.0.0
#   Downloading msgpack-1.0.8-cp310-cp310-win_amd64.whl (75 kB)
#      ---------------------------------------- 75.1/75.1 kB 1.4 MB/s eta 0:00:00
# Requirement already satisfied: colorama in c:\users\user1\appdata\local\programs\python\python310\lib\site-packages (from tqdm>=4.43.0->MDAnalysis) (0.4.5)
# Requirement already satisfied: six>=1.5 in c:\users\user1\appdata\local\programs\python\python310\lib\site-packages (from python-dateutil>=2.7->matplotlib>=1.5.1->MDAnalysis) (1.16.0)
# Installing collected packages: tqdm, threadpoolctl, msgpack, mrcfile, mda-xdrlib, joblib, fasteners, mmtf-python, GridDataFormats, MDAnalysis
# Successfully installed GridDataFormats-1.0.2 MDAnalysis-2.7.0 fasteners-0.19 joblib-1.4.2 mda-xdrlib-0.2.0 mmtf-python-1.1.3 mrcfile-1.5.0 msgpack-1.0.8 threadpoolctl-3.5.0 tqdm-4.66.4
# [notice] A new release of pip available: 22.2.1 -> 24.1.2
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
import MDAnalysis as mda
